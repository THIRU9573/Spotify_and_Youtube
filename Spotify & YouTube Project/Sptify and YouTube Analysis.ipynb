# %% [markdown]
# # Import Required Libraries

# %%
import numpy as np 
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
data =  pd.read_csv('Spotify_Youtuben.csv')

# %%
data

# %% [markdown]
# # TASK 1

# %%
#Task 1: Remove columns that are not needed in our analysis.
# Remove Url_spotify, Uri, Key, Url_youtube, Description
def Remove_columns():
    #do not remove following line of code
    df = pd.read_csv('Spotify_Youtuben.csv')
    
    #WRITE YOUR CODE HERE
    unwanted_columns = ['Url_spotify','Uri','Key','Url_youtube','Description']
    df = df.drop(unwanted_columns, axis = 1)
    

    #return dataframe
    return df

# %%
Remove_columns()
# Out:
#             Artist                                          Track  \
# 0         Gorillaz                                 Feel Good Inc.
# 1         Gorillaz                                Rhinestone Eyes
# 2         Gorillaz  New Gold (feat. Tame Impala and Bootie Brown)
# 3         Gorillaz                             On Melancholy Hill
# 4         Gorillaz                                 Clint Eastwood
# ...            ...                                            ...
# 20718  SICK LEGEND                           JUST DANCE HARDSTYLE
# 20719  SICK LEGEND                 SET FIRE TO THE RAIN HARDSTYLE
# 20720  SICK LEGEND                      OUTSIDE HARDSTYLE SPED UP
# 20721  SICK LEGEND                            ONLY GIRL HARDSTYLE
# 20722  SICK LEGEND                             MISS YOU HARDSTYLE
#
#                                                Album Album_type  Danceability  \
# 0                                         Demon Days      album         0.818
# 1                                      Plastic Beach      album         0.676
# 2      New Gold (feat. Tame Impala and Bootie Brown)     single         0.695
# 3                                      Plastic Beach      album         0.689
# 4                                           Gorillaz      album         0.663
# ...                                              ...        ...           ...
# 20718                           JUST DANCE HARDSTYLE     single         0.582
# 20719                 SET FIRE TO THE RAIN HARDSTYLE     single         0.531
# 20720                      OUTSIDE HARDSTYLE SPED UP     single         0.443
# 20721                            ONLY GIRL HARDSTYLE     single         0.417
# 20722                             MISS YOU HARDSTYLE     single         0.498
#
#        Energy  Loudness  Speechiness  Acousticness  Instrumentalness  ...  \
# 0       0.705    -6.679       0.1770      0.008360          0.002330  ...
# 1       0.703    -5.815       0.0302      0.086900          0.000687  ...
# 2       0.923    -3.930       0.0522      0.042500          0.046900  ...
# 3       0.739    -5.810       0.0260      0.000015          0.509000  ...
# 4       0.694    -8.627       0.1710      0.025300          0.000000  ...
# ...       ...       ...          ...           ...               ...  ...
# 20718   0.926    -6.344       0.0328      0.448000          0.000000  ...
# 20719   0.936    -1.786       0.1370      0.028000          0.000000  ...
# 20720   0.830    -4.679       0.0647      0.024300          0.000000  ...
# 20721   0.767    -4.004       0.4190      0.356000          0.018400  ...
# 20722   0.938    -4.543       0.1070      0.002770          0.911000  ...
#
#          Tempo  Duration_ms  \
# 0      138.559     222640.0
# 1       92.761     200173.0
# 2      108.014     215150.0
# 3      120.423     233867.0
# 4      167.953     340920.0
# ...        ...          ...
# 20718   90.002      94667.0
# 20719  174.869     150857.0
# 20720  168.388     136842.0
# 20721  155.378     108387.0
# 20722  160.067     181500.0
#
#                                                    Title              Channel  \
# 0             Gorillaz - Feel Good Inc. (Official Video)             Gorillaz
# 1      Gorillaz - Rhinestone Eyes [Storyboard Film] (...             Gorillaz
# 2      Gorillaz - New Gold ft. Tame Impala & Bootie B...             Gorillaz
# 3         Gorillaz - On Melancholy Hill (Official Video)             Gorillaz
# 4             Gorillaz - Clint Eastwood (Official Video)             Gorillaz
# ...                                                  ...                  ...
# 20718                               JUST DANCE HARDSTYLE  SICK LEGEND - Topic
# 20719                     SET FIRE TO THE RAIN HARDSTYLE  SICK LEGEND - Topic
# 20720                          OUTSIDE HARDSTYLE SPED UP  SICK LEGEND - Topic
# 20721                                ONLY GIRL HARDSTYLE  SICK LEGEND - Topic
# 20722                                 MISS YOU HARDSTYLE  SICK LEGEND - Topic
#
#              Views      Likes  Comments  Licensed  official_video  \
# 0      693555221.0  6220896.0  169907.0      True            True
# 1       72011645.0  1079128.0   31003.0      True            True
# 2        8435055.0   282142.0    7399.0      True            True
# 3      211754952.0  1788577.0   55229.0      True            True
# 4      618480958.0  6197318.0  155930.0      True            True
# ...            ...        ...       ...       ...             ...
# 20718      71678.0     1113.0       0.0      True            True
# 20719     164741.0     2019.0       0.0      True            True
# 20720      35646.0      329.0       0.0      True            True
# 20721       6533.0       88.0       0.0      True            True
# 20722     158697.0     2484.0       0.0      True            True
#
#              Stream
# 0      1.040235e+09
# 1      3.100837e+08
# 2      6.306347e+07
# 3      4.346636e+08
# 4      6.172597e+08
# ...             ...
# 20718  9.227144e+06
# 20719  1.089818e+07
# 20720  6.226110e+06
# 20721  6.873961e+06
# 20722  5.695584e+06
#
# [20723 rows x 22 columns]

# %% [markdown]
# # TASK 2:

# %%
#Task 2: Check for the null values
def no_of_null_values():
    #Do not remove the following code statment
    df=Remove_columns()


    #WRITE YOUR CODE HERE TO CHECK THE NO OF NULL VALUES AND RETURNS THE SAME
    df = df.isna().sum()

    #return sum of null values by columns
    return df

# %%
 no_of_null_values()
# Out:
# Artist                0
# Track                 0
# Album                 0
# Album_type            0
# Danceability          2
# Energy                2
# Loudness              2
# Speechiness           2
# Acousticness          2
# Instrumentalness      2
# Liveness              2
# Valence               2
# Tempo                 2
# Duration_ms           2
# Title               470
# Channel             470
# Views               470
# Likes               541
# Comments            569
# Licensed            470
# official_video      470
# Stream              577
# dtype: int64

# %%
Remove_columns().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20723 entries, 0 to 20722
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Artist            20723 non-null  object
#  1   Track             20723 non-null  object
#  2   Album             20723 non-null  object
#  3   Album_type        20723 non-null  object
#  4   Danceability      20721 non-null  float64
#  5   Energy            20721 non-null  float64
#  6   Loudness          20721 non-null  float64
#  7   Speechiness       20721 non-null  float64
#  8   Acousticness      20721 non-null  float64
#  9   Instrumentalness  20721 non-null  float64
#  10  Liveness          20721 non-null  float64
#  11  Valence           20721 non-null  float64
#  12  Tempo             20721 non-null  float64
#  13  Duration_ms       20721 non-null  float64
#  14  Title             20253 non-null  object
#  15  Channel           20253 non-null  object
#  16  Views             20253 non-null  float64
#  17  Likes             20182 non-null  float64
#  18  Comments          20154 non-null  float64
#  19  Licensed          20253 non-null  object
#  20  official_video    20253 non-null  object
#  21  Stream            20146 non-null  float64
# dtypes: float64(14), object(8)
# memory usage: 3.5+ MB

# %% [markdown]
# # TASK 3:

# %%
#Task 3: Handle the null values replace int value with 0 and other values with NA
def Handle_Null_values():
    #Do not remove the following code statment
    df=Remove_columns()
    
    #WRITE YOUR CODE HERE ACCORDING TO THE DESCRIPTION
    df['Artist'] =  df['Artist'].fillna("NA")
    df['Track'] =  df['Track'].fillna("NA")
    df['Album'] =  df['Album'].fillna("NA")
    df['Album_type'] = df['Album_type'].fillna("NA")
    df['Danceability'] = df['Danceability'].fillna(0)
    df['Energy'] = df['Energy'].fillna(0)
    df['Loudness'] = df['Loudness'].fillna(0)
    df['Speechiness'] = df['Speechiness'].fillna(0)
    df['Acousticness'] = df['Acousticness'].fillna(0)
    df['Instrumentalness'] = df['Instrumentalness'].fillna(0)
    df['Liveness'] = df['Liveness'].fillna(0)
    df['Valence'] = df['Valence'].fillna(0)
    df['Tempo'] = df['Tempo'].fillna(0)
    df['Duration_ms'] = df['Duration_ms'].fillna(0)
    df['Title'] = df['Title'].fillna("NA")
    df['Channel'] = df['Channel'].fillna("NA")
    df['Views'] = df['Views'].fillna(0)
    df['Likes'] = df['Likes'].fillna(0)
    df['Comments'] = df['Comments'].fillna(0)
    df['Licensed'] = df['Licensed'].fillna("NA")
    df['official_video'] = df['official_video'].fillna("NA")
    df['Stream'] = df['Stream'].fillna(0)

    
    #return dataframe
    return df

# %%
Handle_Null_values().isna().sum()
# Out:
# Artist              0
# Track               0
# Album               0
# Album_type          0
# Danceability        0
# Energy              0
# Loudness            0
# Speechiness         0
# Acousticness        0
# Instrumentalness    0
# Liveness            0
# Valence             0
# Tempo               0
# Duration_ms         0
# Title               0
# Channel             0
# Views               0
# Likes               0
# Comments            0
# Licensed            0
# official_video      0
# Stream              0
# dtype: int64

# %%
Handle_Null_values().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20723 entries, 0 to 20722
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Artist            20723 non-null  object
#  1   Track             20723 non-null  object
#  2   Album             20723 non-null  object
#  3   Album_type        20723 non-null  object
#  4   Danceability      20723 non-null  float64
#  5   Energy            20723 non-null  float64
#  6   Loudness          20723 non-null  float64
#  7   Speechiness       20723 non-null  float64
#  8   Acousticness      20723 non-null  float64
#  9   Instrumentalness  20723 non-null  float64
#  10  Liveness          20723 non-null  float64
#  11  Valence           20723 non-null  float64
#  12  Tempo             20723 non-null  float64
#  13  Duration_ms       20723 non-null  float64
#  14  Title             20723 non-null  object
#  15  Channel           20723 non-null  object
#  16  Views             20723 non-null  float64
#  17  Likes             20723 non-null  float64
#  18  Comments          20723 non-null  float64
#  19  Licensed          20723 non-null  object
#  20  official_video    20723 non-null  object
#  21  Stream            20723 non-null  float64
# dtypes: float64(14), object(8)
# memory usage: 3.5+ MB

# %% [markdown]
# # TASK 4:

# %%
x = Handle_Null_values().duplicated().sum()
print('the number of Duplicated values is {}'.format(x))
# Out:
# the number of Duplicated values is 5

# %%
#Task 4: CHECK FOR DUPLICATES AND REMOVE THEM KEEPING THE FIRST VALUE
def drop_the_duplicates():
    #Do not remove the following code statment
    df=Handle_Null_values()

    #WRITE YOUR CODE HERE
    df = df.drop_duplicates(keep = 'first')

    #return dataframe
    return df

# %%
y = drop_the_duplicates().duplicated().sum()
print('the number of Duplicated values is {}'.format(y))
# Out:
# the number of Duplicated values is 0

# %% [markdown]
# # TASK 5:

# %%
#Task 5: CONVERT millisecond duration to minute for a better understanding
def convert_milisecond_to_Minute():
    #Do not remove the following code statment
    df=drop_the_duplicates()

    #WRITE YOUR CODE HERE
    df['Duration_ms'] = df['Duration_ms'] / 60000

    #return dataframe
    return df

# %%
convert_milisecond_to_Minute()
# Out:
#             Artist                                          Track  \
# 0         Gorillaz                                 Feel Good Inc.
# 1         Gorillaz                                Rhinestone Eyes
# 2         Gorillaz  New Gold (feat. Tame Impala and Bootie Brown)
# 3         Gorillaz                             On Melancholy Hill
# 4         Gorillaz                                 Clint Eastwood
# ...            ...                                            ...
# 20718  SICK LEGEND                           JUST DANCE HARDSTYLE
# 20719  SICK LEGEND                 SET FIRE TO THE RAIN HARDSTYLE
# 20720  SICK LEGEND                      OUTSIDE HARDSTYLE SPED UP
# 20721  SICK LEGEND                            ONLY GIRL HARDSTYLE
# 20722  SICK LEGEND                             MISS YOU HARDSTYLE
#
#                                                Album Album_type  Danceability  \
# 0                                         Demon Days      album         0.818
# 1                                      Plastic Beach      album         0.676
# 2      New Gold (feat. Tame Impala and Bootie Brown)     single         0.695
# 3                                      Plastic Beach      album         0.689
# 4                                           Gorillaz      album         0.663
# ...                                              ...        ...           ...
# 20718                           JUST DANCE HARDSTYLE     single         0.582
# 20719                 SET FIRE TO THE RAIN HARDSTYLE     single         0.531
# 20720                      OUTSIDE HARDSTYLE SPED UP     single         0.443
# 20721                            ONLY GIRL HARDSTYLE     single         0.417
# 20722                             MISS YOU HARDSTYLE     single         0.498
#
#        Energy  Loudness  Speechiness  Acousticness  Instrumentalness  ...  \
# 0       0.705    -6.679       0.1770      0.008360          0.002330  ...
# 1       0.703    -5.815       0.0302      0.086900          0.000687  ...
# 2       0.923    -3.930       0.0522      0.042500          0.046900  ...
# 3       0.739    -5.810       0.0260      0.000015          0.509000  ...
# 4       0.694    -8.627       0.1710      0.025300          0.000000  ...
# ...       ...       ...          ...           ...               ...  ...
# 20718   0.926    -6.344       0.0328      0.448000          0.000000  ...
# 20719   0.936    -1.786       0.1370      0.028000          0.000000  ...
# 20720   0.830    -4.679       0.0647      0.024300          0.000000  ...
# 20721   0.767    -4.004       0.4190      0.356000          0.018400  ...
# 20722   0.938    -4.543       0.1070      0.002770          0.911000  ...
#
#          Tempo  Duration_ms  \
# 0      138.559     3.710667
# 1       92.761     3.336217
# 2      108.014     3.585833
# 3      120.423     3.897783
# 4      167.953     5.682000
# ...        ...          ...
# 20718   90.002     1.577783
# 20719  174.869     2.514283
# 20720  168.388     2.280700
# 20721  155.378     1.806450
# 20722  160.067     3.025000
#
#                                                    Title              Channel  \
# 0             Gorillaz - Feel Good Inc. (Official Video)             Gorillaz
# 1      Gorillaz - Rhinestone Eyes [Storyboard Film] (...             Gorillaz
# 2      Gorillaz - New Gold ft. Tame Impala & Bootie B...             Gorillaz
# 3         Gorillaz - On Melancholy Hill (Official Video)             Gorillaz
# 4             Gorillaz - Clint Eastwood (Official Video)             Gorillaz
# ...                                                  ...                  ...
# 20718                               JUST DANCE HARDSTYLE  SICK LEGEND - Topic
# 20719                     SET FIRE TO THE RAIN HARDSTYLE  SICK LEGEND - Topic
# 20720                          OUTSIDE HARDSTYLE SPED UP  SICK LEGEND - Topic
# 20721                                ONLY GIRL HARDSTYLE  SICK LEGEND - Topic
# 20722                                 MISS YOU HARDSTYLE  SICK LEGEND - Topic
#
#              Views      Likes  Comments  Licensed  official_video  \
# 0      693555221.0  6220896.0  169907.0      True            True
# 1       72011645.0  1079128.0   31003.0      True            True
# 2        8435055.0   282142.0    7399.0      True            True
# 3      211754952.0  1788577.0   55229.0      True            True
# 4      618480958.0  6197318.0  155930.0      True            True
# ...            ...        ...       ...       ...             ...
# 20718      71678.0     1113.0       0.0      True            True
# 20719     164741.0     2019.0       0.0      True            True
# 20720      35646.0      329.0       0.0      True            True
# 20721       6533.0       88.0       0.0      True            True
# 20722     158697.0     2484.0       0.0      True            True
#
#              Stream
# 0      1.040235e+09
# 1      3.100837e+08
# 2      6.306347e+07
# 3      4.346636e+08
# 4      6.172597e+08
# ...             ...
# 20718  9.227144e+06
# 20719  1.089818e+07
# 20720  6.226110e+06
# 20721  6.873961e+06
# 20722  5.695584e+06
#
# [20718 rows x 22 columns]

# %% [markdown]
# # TASK 6:

# %%
#Task 6: Rename the modified column to Duration_min
def rename_modified_column():
    #Do not remove the following code statment
    df=convert_milisecond_to_Minute()

    #WRITE YOUR CODE HERE
    df = df.rename(columns = {'Duration_ms': 'Duration_min'})

    #return dataframe
    return df

# %% [markdown]
# # TASK 7:

# %%
#Task 7: Remove irrelevant 'Track' name that starts with ?
def Irrelevant_Track_name():
    #Do not remove the following code statment
    df=rename_modified_column()

    #WRITE YOUR CODE HERE
    df = df[~df["Track"].str.startswith("?")]



    #return dataframe
    return df

# %% [markdown]
# # TASK 8:

# %%
#Task 8: Calculate the Energy to Liveness ratio for each track and store it in columns 'EnergyLiveness'
def Energy_to_liveness_Ratio():
    #Do not remove the following code statment
    df=Irrelevant_Track_name()

    #WRITE YOUR CODE HERE
    df['EnergyLiveness']=df['Energy']/df['Liveness']


    #return dataframe
    return df

# %%
Energy_to_liveness_Ratio().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20594 entries, 0 to 20722
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Artist            20594 non-null  object
#  1   Track             20594 non-null  object
#  2   Album             20594 non-null  object
#  3   Album_type        20594 non-null  object
#  4   Danceability      20594 non-null  float64
#  5   Energy            20594 non-null  float64
#  6   Loudness          20594 non-null  float64
#  7   Speechiness       20594 non-null  float64
#  8   Acousticness      20594 non-null  float64
#  9   Instrumentalness  20594 non-null  float64
#  10  Liveness          20594 non-null  float64
#  11  Valence           20594 non-null  float64
#  12  Tempo             20594 non-null  float64
#  13  Duration_min      20594 non-null  float64
#  14  Title             20594 non-null  object
#  15  Channel           20594 non-null  object
#  16  Views             20594 non-null  float64
#  17  Likes             20594 non-null  float64
#  18  Comments          20594 non-null  float64
#  19  Licensed          20594 non-null  object
#  20  official_video    20594 non-null  object
#  21  Stream            20594 non-null  float64
#  22  EnergyLiveness    20592 non-null  float64
# dtypes: float64(15), object(8)
# memory usage: 3.8+ MB

# %% [markdown]
# # TASK 9

# %%
#Task 9: change the datatype of 'views' to float for further use
def change_the_datatype():
    #Do not remove the following code statment
    df=Energy_to_liveness_Ratio()

    #WRITE YOUR CODE HERE
    df['Views'] = df['Views'].astype('float')


    #return dataframe
    return df

# %%
change_the_datatype()
# Out:
#             Artist                                          Track  \
# 0         Gorillaz                                 Feel Good Inc.
# 1         Gorillaz                                Rhinestone Eyes
# 2         Gorillaz  New Gold (feat. Tame Impala and Bootie Brown)
# 3         Gorillaz                             On Melancholy Hill
# 4         Gorillaz                                 Clint Eastwood
# ...            ...                                            ...
# 20718  SICK LEGEND                           JUST DANCE HARDSTYLE
# 20719  SICK LEGEND                 SET FIRE TO THE RAIN HARDSTYLE
# 20720  SICK LEGEND                      OUTSIDE HARDSTYLE SPED UP
# 20721  SICK LEGEND                            ONLY GIRL HARDSTYLE
# 20722  SICK LEGEND                             MISS YOU HARDSTYLE
#
#                                                Album Album_type  Danceability  \
# 0                                         Demon Days      album         0.818
# 1                                      Plastic Beach      album         0.676
# 2      New Gold (feat. Tame Impala and Bootie Brown)     single         0.695
# 3                                      Plastic Beach      album         0.689
# 4                                           Gorillaz      album         0.663
# ...                                              ...        ...           ...
# 20718                           JUST DANCE HARDSTYLE     single         0.582
# 20719                 SET FIRE TO THE RAIN HARDSTYLE     single         0.531
# 20720                      OUTSIDE HARDSTYLE SPED UP     single         0.443
# 20721                            ONLY GIRL HARDSTYLE     single         0.417
# 20722                             MISS YOU HARDSTYLE     single         0.498
#
#        Energy  Loudness  Speechiness  Acousticness  Instrumentalness  ...  \
# 0       0.705    -6.679       0.1770      0.008360          0.002330  ...
# 1       0.703    -5.815       0.0302      0.086900          0.000687  ...
# 2       0.923    -3.930       0.0522      0.042500          0.046900  ...
# 3       0.739    -5.810       0.0260      0.000015          0.509000  ...
# 4       0.694    -8.627       0.1710      0.025300          0.000000  ...
# ...       ...       ...          ...           ...               ...  ...
# 20718   0.926    -6.344       0.0328      0.448000          0.000000  ...
# 20719   0.936    -1.786       0.1370      0.028000          0.000000  ...
# 20720   0.830    -4.679       0.0647      0.024300          0.000000  ...
# 20721   0.767    -4.004       0.4190      0.356000          0.018400  ...
# 20722   0.938    -4.543       0.1070      0.002770          0.911000  ...
#
#        Duration_min                                              Title  \
# 0          3.710667         Gorillaz - Feel Good Inc. (Official Video)
# 1          3.336217  Gorillaz - Rhinestone Eyes [Storyboard Film] (...
# 2          3.585833  Gorillaz - New Gold ft. Tame Impala & Bootie B...
# 3          3.897783     Gorillaz - On Melancholy Hill (Official Video)
# 4          5.682000         Gorillaz - Clint Eastwood (Official Video)
# ...             ...                                                ...
# 20718      1.577783                               JUST DANCE HARDSTYLE
# 20719      2.514283                     SET FIRE TO THE RAIN HARDSTYLE
# 20720      2.280700                          OUTSIDE HARDSTYLE SPED UP
# 20721      1.806450                                ONLY GIRL HARDSTYLE
# 20722      3.025000                                 MISS YOU HARDSTYLE
#
#                    Channel        Views      Likes  Comments  Licensed  \
# 0                 Gorillaz  693555221.0  6220896.0  169907.0      True
# 1                 Gorillaz   72011645.0  1079128.0   31003.0      True
# 2                 Gorillaz    8435055.0   282142.0    7399.0      True
# 3                 Gorillaz  211754952.0  1788577.0   55229.0      True
# 4                 Gorillaz  618480958.0  6197318.0  155930.0      True
# ...                    ...          ...        ...       ...       ...
# 20718  SICK LEGEND - Topic      71678.0     1113.0       0.0      True
# 20719  SICK LEGEND - Topic     164741.0     2019.0       0.0      True
# 20720  SICK LEGEND - Topic      35646.0      329.0       0.0      True
# 20721  SICK LEGEND - Topic       6533.0       88.0       0.0      True
# 20722  SICK LEGEND - Topic     158697.0     2484.0       0.0      True
#
#        official_video        Stream EnergyLiveness
# 0                True  1.040235e+09       1.150082
# 1                True  3.100837e+08      15.183585
# 2                True  6.306347e+07       7.956897
# 3                True  4.346636e+08      11.546875
# 4                True  6.172597e+08       9.942693
# ...               ...           ...            ...
# 20718            True  9.227144e+06      11.036949
# 20719            True  1.089818e+07      10.140845
# 20720            True  6.226110e+06       5.389610
# 20721            True  6.873961e+06       7.101852
# 20722            True  5.695584e+06       6.897059
#
# [20594 rows x 23 columns]

# %% [markdown]
# # TASK 10:

# %%
#Task 10: compare the views and stream columns to infer
# that the song track was more played on which platform, youtube or Spotify.
# Create a column named most_playedon which will have two values.
# Spotify and Youtube,If a song track is most played on youtube then
# the most_played on column will have youtube as the value for that particular song
def compare_the_views():
    #Do not remove the following code statment
    df=change_the_datatype()

    #WRITE YOUR CODE HERE
    # Compare 'Views' and 'Stream' columns to infer the most played platform
    df['most_playedon'] = df.apply(lambda x:'Spotify' if x['Stream'] > x['Views'] else 'Youtube', axis =1)



    #return dataframe
    return df

# %% [markdown]
# # Task 11:

# %%
#Task 11: export the cleaned dataset to CSV to "cleaned_dataset.csv"
def export_the_cleaned_dataset():
    #Do not remove the following code statment
    df=compare_the_views()
    
    #WRITE YOUR CODE HERE
    #create csv file "cleaned_dataset.csv" using dataframe
    df.to_csv("cleaned_dataset.csv")
    return df
    
    
export_the_cleaned_dataset()
#TASK 12
#follow the instruction in the Task 13 description and complete the task as per it.

#check if mysql table is created using "cleaned_dataset.csv"
#Use this final dataset and upload it on the provided database for performing analysis in  MySQL
#To run this task click on the terminal and click on the run projec
# Out:
#             Artist                                          Track  \
# 0         Gorillaz                                 Feel Good Inc.
# 1         Gorillaz                                Rhinestone Eyes
# 2         Gorillaz  New Gold (feat. Tame Impala and Bootie Brown)
# 3         Gorillaz                             On Melancholy Hill
# 4         Gorillaz                                 Clint Eastwood
# ...            ...                                            ...
# 20718  SICK LEGEND                           JUST DANCE HARDSTYLE
# 20719  SICK LEGEND                 SET FIRE TO THE RAIN HARDSTYLE
# 20720  SICK LEGEND                      OUTSIDE HARDSTYLE SPED UP
# 20721  SICK LEGEND                            ONLY GIRL HARDSTYLE
# 20722  SICK LEGEND                             MISS YOU HARDSTYLE
#
#                                                Album Album_type  Danceability  \
# 0                                         Demon Days      album         0.818
# 1                                      Plastic Beach      album         0.676
# 2      New Gold (feat. Tame Impala and Bootie Brown)     single         0.695
# 3                                      Plastic Beach      album         0.689
# 4                                           Gorillaz      album         0.663
# ...                                              ...        ...           ...
# 20718                           JUST DANCE HARDSTYLE     single         0.582
# 20719                 SET FIRE TO THE RAIN HARDSTYLE     single         0.531
# 20720                      OUTSIDE HARDSTYLE SPED UP     single         0.443
# 20721                            ONLY GIRL HARDSTYLE     single         0.417
# 20722                             MISS YOU HARDSTYLE     single         0.498
#
#        Energy  Loudness  Speechiness  Acousticness  Instrumentalness  ...  \
# 0       0.705    -6.679       0.1770      0.008360          0.002330  ...
# 1       0.703    -5.815       0.0302      0.086900          0.000687  ...
# 2       0.923    -3.930       0.0522      0.042500          0.046900  ...
# 3       0.739    -5.810       0.0260      0.000015          0.509000  ...
# 4       0.694    -8.627       0.1710      0.025300          0.000000  ...
# ...       ...       ...          ...           ...               ...  ...
# 20718   0.926    -6.344       0.0328      0.448000          0.000000  ...
# 20719   0.936    -1.786       0.1370      0.028000          0.000000  ...
# 20720   0.830    -4.679       0.0647      0.024300          0.000000  ...
# 20721   0.767    -4.004       0.4190      0.356000          0.018400  ...
# 20722   0.938    -4.543       0.1070      0.002770          0.911000  ...
#
#                                                    Title              Channel  \
# 0             Gorillaz - Feel Good Inc. (Official Video)             Gorillaz
# 1      Gorillaz - Rhinestone Eyes [Storyboard Film] (...             Gorillaz
# 2      Gorillaz - New Gold ft. Tame Impala & Bootie B...             Gorillaz
# 3         Gorillaz - On Melancholy Hill (Official Video)             Gorillaz
# 4             Gorillaz - Clint Eastwood (Official Video)             Gorillaz
# ...                                                  ...                  ...
# 20718                               JUST DANCE HARDSTYLE  SICK LEGEND - Topic
# 20719                     SET FIRE TO THE RAIN HARDSTYLE  SICK LEGEND - Topic
# 20720                          OUTSIDE HARDSTYLE SPED UP  SICK LEGEND - Topic
# 20721                                ONLY GIRL HARDSTYLE  SICK LEGEND - Topic
# 20722                                 MISS YOU HARDSTYLE  SICK LEGEND - Topic
#
#              Views      Likes  Comments Licensed  official_video  \
# 0      693555221.0  6220896.0  169907.0     True            True
# 1       72011645.0  1079128.0   31003.0     True            True
# 2        8435055.0   282142.0    7399.0     True            True
# 3      211754952.0  1788577.0   55229.0     True            True
# 4      618480958.0  6197318.0  155930.0     True            True
# ...            ...        ...       ...      ...             ...
# 20718      71678.0     1113.0       0.0     True            True
# 20719     164741.0     2019.0       0.0     True            True
# 20720      35646.0      329.0       0.0     True            True
# 20721       6533.0       88.0       0.0     True            True
# 20722     158697.0     2484.0       0.0     True            True
#
#              Stream  EnergyLiveness most_playedon
# 0      1.040235e+09        1.150082       Spotify
# 1      3.100837e+08       15.183585       Spotify
# 2      6.306347e+07        7.956897       Spotify
# 3      4.346636e+08       11.546875       Spotify
# 4      6.172597e+08        9.942693       Youtube
# ...             ...             ...           ...
# 20718  9.227144e+06       11.036949       Spotify
# 20719  1.089818e+07       10.140845       Spotify
# 20720  6.226110e+06        5.389610       Spotify
# 20721  6.873961e+06        7.101852       Spotify
# 20722  5.695584e+06        6.897059       Spotify
#
# [20594 rows x 24 columns]

# %%
import pandas as pd 
from sqlalchemy import create_engine
import time 
import pymysql

def timing_decorator(func):
    def wrapper(*args, **kwargs):
        start_time = time.time()
        result = func(*args, **kwargs)
        end_time = time.time()
        print(f"the execution time is {end_time - start_time} seconds")
        return result
    return wrapper

conn = create_engine("mysql+pymysql://root:THIru980@localhost:3306/spotify_youtube")

@timing_decorator
def load_csv_with_pamdas():
    data = pd.read_csv("cleaned_dataset.csv")
    data.to_sql("cleaned_dataset", conn, if_exists = "append", chunksize = 100, index = False)
    
load_csv_with_pamdas()
# Out:
# the execution time is 6.001147270202637 seconds

# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

#do not change the predefined function names

#Task 1: Remove columns that are not needed in our analysis.
# Remove Url_spotify, Uri, Key, Url_youtube, Description
def Remove_columns():
    #do not remove following line of code
    df = pd.read_csv('Spotify_Youtuben.csv')
    
    #WRITE YOUR CODE HERE

    #return dataframe
    return df


#Task 2: Check for the null values
def no_of_null_values():
    #Do not remove the following code statment
    df=Remove_columns()


    #WRITE YOUR CODE HERE TO CHECK THE NO OF NULL VALUES AND RETURNS THE SAME

    #return sum of null values by columns
    return df
    

#Task 3: Handle the null values replace int value with 0 and other values with NA
def Handle_Null_values():
    #Do not remove the following code statment
    df=Remove_columns()
    
    #WRITE YOUR CODE HERE ACCORDING TO THE DESCRIPTION
    

    #return dataframe
    return df

#Task 4: CHECK FOR DUPLICATES AND REMOVE THEM KEEPING THE FIRST VALUE
def drop_the_duplicates():
    #Do not remove the following code statment
    df=Handle_Null_values()

    #WRITE YOUR CODE HERE

    #return dataframe
    return df

#Task 5: CONVERT millisecond duration to minute for a better understanding
def convert_milisecond_to_Minute():
    #Do not remove the following code statment
    df=drop_the_duplicates()

    #WRITE YOUR CODE HERE

    #return dataframe
    return df

#Task 6: Rename the modified column to Duration_min
def rename_modified_column():
    #Do not remove the following code statment
    df=convert_milisecond_to_Minute()

    #WRITE YOUR CODE HERE

    #return dataframe
    return df

#Task 7: Remove irrelevant 'Track' name that starts with ?
def Irrelevant_Track_name():
    #Do not remove the following code statment
    df=rename_modified_column()

    #WRITE YOUR CODE HERE

    #return dataframe
    return df

#Task 8: Calculate the Energy to Liveness ratio for each track and store it in columns 'EnergyLiveness'
def Energy_to_liveness_Ratio():
    #Do not remove the following code statment
    df=Irrelevant_Track_name()

    #WRITE YOUR CODE HERE


    #return dataframe
    return df

#Task 9: change the datatype of 'views' to float for further use
def change_the_datatype():
    #Do not remove the following code statment
    df=Energy_to_liveness_Ratio()

    #WRITE YOUR CODE HERE

    #return dataframe
    return df

#Task 10: compare the views and stream columns to infer
# that the song track was more played on which platform, youtube or Spotify.
# Create a column named most_playedon which will have two values.
# Spotify and Youtube,If a song track is most played on youtube then
# the most_played on column will have youtube as the value for that particular song
def compare_the_views():
    #Do not remove the following code statment
    df=change_the_datatype()

    #WRITE YOUR CODE HERE

    #return dataframe
    return df

#Task 11: export the cleaned dataset to CSV to "cleaned_dataset.csv"
def export_the_cleaned_dataset():
    #Do not remove the following code statment
    df=compare_the_views()
    
    #WRITE YOUR CODE HERE
    #create csv file "cleaned_dataset.csv" using dataframe
    


#TASK 12
#follow the instruction in the Task 13 description and complete the task as per it.

#check if mysql table is created using "cleaned_dataset.csv"
#Use this final dataset and upload it on the provided database for performing analysis in  MySQL
#To run this task click on the terminal and click on the run project
